# %% [markdown]
# # Open Police data project
#
# I want to analyse open police data from two different cities in the US between slightly different time frames.
# 1) San Fransico, California (Jan 2007 - Jun 2016)
#
# 2) Nashville, Tennessee (Jan 2010 - Mar 2019)
#
# The are that will be explored:
# 1) Impact of gender on crime
#
# 2) Impact of race on crime
#
# 3) Impact of weather on crime

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20, 10)

import pandas_profiling

# %%
cols_to_keep_san_fran = ['date', 
                         'time', 
                         'warning_issued',
                         'citation_issued',
                         'search_vehicle',
                         'outcome',
                         'district',
                         'subject_age',
                         'contraband_found',
                         'subject_race',
                         'subject_sex',
                         'arrest_made',
                         'reason_for_stop']

# Jan 2007 - Jun 2016
san_fran = pd.read_csv(r'C:\Users\harpo\Documents\Data Science Work\projects in progress\Open Police data\ca_san_francisco_2020_04_01.csv',
                      parse_dates=[['date', 'time']],
                      usecols=cols_to_keep_san_fran)

cols_to_keep_nashville = ['date', 
                         'time', 
                         'location',
                         'search_vehicle',
                         'search_basis',
                         'outcome',
                         'subject_age',
                         'contraband_found',
                         'contraband_drugs',
                         'contraband_weapons',
                         'frisk_performed',
                         'subject_race',
                         'subject_sex',
                         'reason_for_stop']

# Jan 2010 - Mar 2019
nashville = pd.read_csv(r'C:\Users\harpo\Documents\Data Science Work\projects in progress\Open Police data\tn_nashville_2020_04_01.csv',
                       parse_dates=[['date', 'time']],
                       usecols=cols_to_keep_nashville)
# Out:
# C:\Users\harpo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\harpo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (22,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Pandas profiling
#san_fran_report = pandas_profiling.ProfileReport(san_fran)
#san_fran_report.to_notebook_iframe()

#"san_fran_report_preprocessing.html")

#nashville_report = pandas_profiling.ProfileReport(nashville)
#nashville_report.to_notebook_iframe()
#nashville_report.tofile('nashville_report_preprocessing.html')

# %%
# Set 'date_time' as the index
san_fran.set_index('date_time', inplace=True)

display(san_fran)
# Out:
#                     district  subject_age            subject_race subject_sex  \
# date_time
# 2014-08-01 00:01:00      NaN          NaN  asian/pacific islander      female
# 2014-08-01 00:01:00      NaN          NaN                   black        male
# 2014-08-01 00:15:00      NaN          NaN                hispanic        male
# 2014-08-01 00:18:00      NaN          NaN                hispanic        male
# 2014-08-01 00:19:00      NaN          NaN                   white        male
# ...                      ...          ...                     ...         ...
# 2014-10-31 23:47:00      NaN          NaN                   white        male
# 2014-10-31 23:48:00      NaN          NaN  asian/pacific islander        male
# 2014-10-31 23:49:00      NaN          NaN                   white        male
# 2014-10-31 23:50:00      NaN          NaN                   black        male
# 2014-10-31 23:50:00      NaN          NaN                   white        male
#
# ...

# %% [markdown]
# ### Do different genders commit different offences

# %%
# Count the unique values in 'reason_for_stop' (value_counts)

#display(san_fran['reason_for_stop'].value_counts())

# Express the counts as proportions

san_fran['reason_for_stop'].value_counts(normalize=True).plot(kind='bar',stacked=True)
plt.show()

# divide the dataframe up into to male and female and 
# plot the value_counts as proportions of the types of violations each gender commits

# %% [markdown]
# When a driver is pulled over for speeding, many people believe that gender has an impact on whether the driver will receive a ticket or a warning. Can you find evidence of this in the dataset?

# %%
# Create a DataFrame of female and male drivers stopped for speeding (violation column)

# %% [markdown]
# Does search rate vary between genders

# %% [markdown]
# Counting protective frisks, does gender make a difference here

# %% [markdown]
# Does time of day affect arrest rate? time series plot

# %% [markdown]
# Has drug related stops increased over time.
# The Boolean column drugs_related_stop indicates whether drugs were found during a given stop.

# %% [markdown]
# What violations are caught in each district?
#
# also make a cross tab of driver race and gender

# %% [markdown]
# How long might you be stopped for a violation?

# %% [markdown]
# Does weather have an impact on police behaviour. Find the weather station closest to the cities studied.
